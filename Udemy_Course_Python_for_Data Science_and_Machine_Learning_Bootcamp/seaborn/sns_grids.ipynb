# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)

# %%
tips = sns.load_dataset('tips')

# %%
j = sns.FacetGrid(data = tips,col='time',row='smoker')

# %%
j.map(plt.scatter,'total_bill','tip')
plt.show()
