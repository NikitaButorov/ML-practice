# %%
import pandas as pd
import numpy as np
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import chart_studio.plotly as py
import plotly.express as px
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>

# %%
df = pd.DataFrame(np.random.randn(100,4), columns = 'A B C D'.split())
df
# Out:
#            A         B         C         D
# 0  -0.823933 -0.505176 -0.656604  0.001651
# 1   0.776792 -2.741472 -0.315993  0.427276
# 2   0.784678  1.182128 -0.775443 -0.539330
# 3  -0.270064 -1.350103 -0.651433 -0.195327
# 4  -0.967151 -0.674772 -2.204686 -0.694327
# ..       ...       ...       ...       ...
# 95 -0.195684  1.166069 -1.168327  1.371736
# 96  0.618839  1.384766  1.625551 -1.168379
# 97 -0.054200  0.330945  0.526079  0.249909
# 98  0.652790 -0.350505 -0.112567  2.110427
# 99 -0.620528  1.051882  0.292244  0.719435
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
fig = px.scatter(df,x='A',y="B")
fig.show()

# %%
fig = px.bar(df2,x='Category',y="Values")
fig.show()
